# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
dfx = pd.read_csv('.\Diabetes_XTrain.csv')
dfx.plot.bar()
plt.show()

# %%
x = dfx.values
list=[]
for i in range(x.shape[1]):
    x1 = x[:,i].mean()
    list.append(x1)
list
# Out:
# [3.7586805555555554,
#  119.97569444444444,
#  68.82638888888889,
#  20.364583333333332,
#  76.16666666666667,
#  31.857291666666665,
#  0.48151909722222225,
#  32.954861111111114]

# %%
x = dfx
plt.bar([1,2,3,4,5,6,7,8],list,tick_label=x.columns,color='b',width=0.8)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.hist(x['Pregnancies'],rwidth=0.8,color='green')
plt.show()

# %%
plt.hist(x['Glucose'], rwidth=0.8,color='violet')
plt.show()

# %%
plt.hist(x['BloodPressure'],rwidth=0.8, color='red')
plt.show()

# %%
plt.hist(x['SkinThickness'],rwidth=0.8,color='orange')
plt.show()

# %%
plt.hist(x['Insulin'], rwidth=0.8,color='cyan')
plt.show()

# %%
plt.hist(x['BMI'], rwidth=0.8, color='gray')
plt.show()

# %%
plt.hist(x['DiabetesPedigreeFunction'], rwidth=0.8,color='brown')
plt.show()

# %%
plt.hist(x['Age'],rwidth=0.8, color='yellow')
plt.show()

# %%
x = dfx.values

# %%
x
# Out:
# array([[  7.   , 168.   ,  88.   , ...,  38.2  ,   0.787,  40.   ],
#        [  8.   , 110.   ,  76.   , ...,  27.8  ,   0.237,  58.   ],
#        [  7.   , 147.   ,  76.   , ...,  39.4  ,   0.257,  43.   ],
#        ...,
#        [  2.   , 122.   ,  60.   , ...,  29.8  ,   0.717,  22.   ],
#        [  4.   , 154.   ,  72.   , ...,  31.3  ,   0.338,  37.   ],
#        [  1.   ,  88.   ,  78.   , ...,  32.   ,   0.365,  29.   ]])

# %%
x.shape
# Out:
# (576, 8)

# %%
dfy = pd.read_csv('.\Diabetes_YTrain.csv')

# %%
df3 = pd.read_csv('.\Diabetes_Xtest.csv')
xtest = df3.values

# %%
y = dfy.values
y = y.reshape(-1)

# %%
y.shape
# Out:
# (576,)

# %%
#KNN
def distance(x1,x2):
    return np.sqrt(sum((x1-x2)**2))

#KNN Algo
def knn(x,y,querypoint,k=5):
    
    #Pick k-nearest neighbours
    vals = []
    
    #for every point in the x
    for i in range(x.shape[0]):
        #Compute Distance
        d = distance(querypoint,x[i])
        vals.append((d,int(y[i])))
        
    #print(vals)
    
    #2. Sort the arrays & give k-nearest points
    vals = sorted(vals,key=lambda x:x[0])[:k]
    
    #vals = vals[:k]
    
    #Majority Vote
    vals = np.array(vals,dtype=np.int64)
    new_values = np.unique(vals[:,1], return_counts=True)
    print(new_values)
    
    #Index of MAximum COunt
    index=new_values[1].argmax()
    
    #Map this index with my data
    pred = new_values[0][index]
    
    return pred

# %%
res = knn(x,y,x[24])
res
# Out:
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# 0

# %%
for i in range(x.shape[0]):
    res = knn(x,y,x[i])
# Out:
# (array([0, 1], dtype=int64), array([1, 4], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0, 1], dtype=int64), array([3, 2], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0], dtype=int64), array([5], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0, 1], dtype=int64), array([1, 4], dtype=int64))
# (array([0], dtype=int64), array([5], dtype=int64))
# (array([0], dtype=int64), array([5], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0], dtype=int64), array([5], dtype=int64))
# (array([0, 1], dtype=int64), array([3, 2], dtype=int64))
# (array([1], dtype=int64), array([5], dtype=int64))
# (array([0, 1], dtype=int64), array([4, 1], dtype=int64))
# (array([0, 1], dtype=int64), array([3, 2], dtype=int64))
# ...
